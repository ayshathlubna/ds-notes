# %% [markdown]
# # Pandas
# - **Pandas** is a fast, powerful and easy to use open source data analysis and manipulation library.
# 1. Series
# 2. DataFrame

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Series

# %%
data = [10,20,30,40,50]
s1 = pd.Series(data)
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.values
# Out:
# array([10, 20, 30, 40, 50], dtype=int64)

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
list(s1.index)
# Out:
# [0, 1, 2, 3, 4]

# %%
s1.index = [101,102,103,104,105]
s1
# Out:
# 101    10
# 102    20
# 103    30
# 104    40
# 105    50
# dtype: int64

# %%
s1.index = ['A', 'B', 'C', 'D', 'E']
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
s1.index = range(1001,1006)
s1
# Out:
# 1001    10
# 1002    20
# 1003    30
# 1004    40
# 1005    50
# dtype: int64

# %%
s1.index = [1.5,2.5,3.5,4.5,5.7]
s1
# Out:
# 1.5    10
# 2.5    20
# 3.5    30
# 4.5    40
# 5.7    50
# dtype: int64

# %%
s1.index = ['A', 'B', 'C', 'D', 'E']
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# ## Accessing data in Series

# %%
s1[0]
# Out:
# 10

# %%
s1[1]
# Out:
# 20

# %%
s1[-1]
# Out:
# 50

# %%
s1['A']
# Out:
# 10

# %%
s1['B']
# Out:
# 20

# %%
s1['D']
# Out:
# 40

# %%
s1.iloc[0]                       # By positional indexing
# Out:
# 10

# %%
s1.iloc[[0,1]]
# Out:
# A    10
# B    20
# dtype: int64

# %%
s1.loc['A']                      # By index that has been provided
# Out:
# 10

# %%
s1.loc[['A','B']]
# Out:
# A    10
# B    20
# dtype: int64

# %% [markdown]
# ## Add, update and Delete operations

# %%
s1['F'] = 60
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# dtype: int64

# %%
s1['D'] = 80
s1
# Out:
# A    10
# B    20
# C    30
# D    80
# E    50
# F    60
# dtype: int64

# %%
s1.drop('D', inplace = True)

# %%
s1
# Out:
# A    10
# B    20
# C    30
# E    50
# F    60
# dtype: int64

# %% [markdown]
# ## Slicing

# %%
s1[:]
# Out:
# A    10
# B    20
# C    30
# E    50
# F    60
# dtype: int64

# %%
s1[2:5]
# Out:
# C    30
# E    50
# F    60
# dtype: int64

# %%
s1[-1::-1]
# Out:
# F    60
# E    50
# C    30
# B    20
# A    10
# dtype: int64

# %%
s1[::2]
# Out:
# A    10
# C    30
# F    60
# dtype: int64

# %% [markdown]
# ## Creating Series from Dictionary

# %%
data = {'Mohit' : 85,
        'Ankit' : 80,
        'Anjali': 86,
        'Varun' : 81}
s = pd.Series(data)
s
# Out:
# Mohit     85
# Ankit     80
# Anjali    86
# Varun     81
# dtype: int64

# %%
data = {'Jaipur' : 'Rajasthan',
        'Mumbai' : 'Maharashtra',
        'Kolkata': 'West Bengal',
        'Chandigarh' : 'Punjab',
        'Bengaluru' : 'Karnataka'}
data
# Out:
# {'Jaipur': 'Rajasthan',
#  'Mumbai': 'Maharashtra',
#  'Kolkata': 'West Bengal',
#  'Chandigarh': 'Punjab',
#  'Bengaluru': 'Karnataka'}

# %%
s2 = pd.Series(data)
s2
# Out:
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# dtype: object

# %%
s2['Jaipur']
# Out:
# 'Rajasthan'

# %%
s2.index
# Out:
# Index(['Jaipur', 'Mumbai', 'Kolkata', 'Chandigarh', 'Bengaluru'], dtype='object')

# %%
s2.values
# Out:
# array(['Rajasthan', 'Maharashtra', 'West Bengal', 'Punjab', 'Karnataka'],
#       dtype=object)

# %%
s2[0]
# Out:
# 'Rajasthan'

# %%
s2.loc['Jaipur']
# Out:
# 'Rajasthan'

# %%
s2.iloc[0]
# Out:
# 'Rajasthan'

# %%
s2.name = 'States and Capitals'
s2
# Out:
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# Name: States and Capitals, dtype: object

# %%
s2.name
# Out:
# 'States and Capitals'

# %%
s2.index.name = 'Capitals'
s2
# Out:
# Capitals
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# Name: States and Capitals, dtype: object

# %%
print(s2.index)
print(s2.values)
print(s2.dtype)
print(s2.name)
print(s2.index.name)
# Out:
# Index(['Jaipur', 'Mumbai', 'Kolkata', 'Chandigarh', 'Bengaluru'], dtype='object', name='Capitals')
# ['Rajasthan' 'Maharashtra' 'West Bengal' 'Punjab' 'Karnataka']
# object
# States and Capitals
# Capitals

# %%
s2[['Jaipur','Mumbai','Kolkata']]
# Out:
# Capitals
# Jaipur       Rajasthan
# Mumbai     Maharashtra
# Kolkata    West Bengal
# Name: States and Capitals, dtype: object

# %%
roll_no = [101,102,103,104,105]
result = [88,89,93,85,96]

s3 = pd.Series(data = result, index = roll_no)
s3.name = 'Final Result'
s3.index.name = 'Roll No'
s3
# Out:
# Roll No
# 101    88
# 102    89
# 103    93
# 104    85
# 105    96
# Name: Final Result, dtype: int64

# %%
s2
# Out:
# Capitals
# Jaipur          Rajasthan
# Mumbai        Maharashtra
# Kolkata       West Bengal
# Chandigarh         Punjab
# Bengaluru       Karnataka
# Name: States and Capitals, dtype: object

# %%
capitals = ['Jaipur', 'Kolkata', 'Mumbai']
s4 = pd.Series(data = s2, index = capitals)
s4
# Out:
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Mumbai     Maharashtra
# Name: States and Capitals, dtype: object

# %%
capitals = ['Jaipur', 'Kolkata', 'Mumbai', 'Delhi','Chennai']
s5 = pd.Series(data = s2, index = capitals)
s5
# Out:
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Mumbai     Maharashtra
# Delhi              NaN
# Chennai            NaN
# Name: States and Capitals, dtype: object

# %% [markdown]
# ## Functions

# %%
s5.isnull()                               # Check for missing values
# Out:
# Jaipur     False
# Kolkata    False
# Mumbai     False
# Delhi       True
# Chennai     True
# Name: States and Capitals, dtype: bool

# %%
s5.notnull()
# Out:
# Jaipur      True
# Kolkata     True
# Mumbai      True
# Delhi      False
# Chennai    False
# Name: States and Capitals, dtype: bool

# %%
s5.isnull().sum()
# Out:
# 2

# %%
s5['Bengaluru'] = 'Karnataka'
s5
# Out:
# Jaipur         Rajasthan
# Kolkata      West Bengal
# Mumbai       Maharashtra
# Delhi                NaN
# Chennai              NaN
# Bengaluru      Karnataka
# Name: States and Capitals, dtype: object

# %%
s5.head()
# Out:
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Mumbai     Maharashtra
# Delhi              NaN
# Chennai            NaN
# Name: States and Capitals, dtype: object

# %%
s5.head(3)
# Out:
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Mumbai     Maharashtra
# Name: States and Capitals, dtype: object

# %%
s5.tail()
# Out:
# Kolkata      West Bengal
# Mumbai       Maharashtra
# Delhi                NaN
# Chennai              NaN
# Bengaluru      Karnataka
# Name: States and Capitals, dtype: object

# %%
s5.tail(3)
# Out:
# Delhi              NaN
# Chennai            NaN
# Bengaluru    Karnataka
# Name: States and Capitals, dtype: object

# %%
s5['Pune'] = 'Maharashtra'
s5
# Out:
# Jaipur         Rajasthan
# Kolkata      West Bengal
# Mumbai       Maharashtra
# Delhi                NaN
# Chennai              NaN
# Bengaluru      Karnataka
# Pune         Maharashtra
# Name: States and Capitals, dtype: object

# %%
s5.index = range(101,108)
s5
# Out:
# 101      Rajasthan
# 102    West Bengal
# 103    Maharashtra
# 104            NaN
# 105            NaN
# 106      Karnataka
# 107    Maharashtra
# Name: States and Capitals, dtype: object

# %%
s5[108] = 'Maharashtra'
s5[109] = 'Maharashtra'
s5
# Out:
# 101      Rajasthan
# 102    West Bengal
# 103    Maharashtra
# 104            NaN
# 105            NaN
# 106      Karnataka
# 107    Maharashtra
# 108    Maharashtra
# 109    Maharashtra
# Name: States and Capitals, dtype: object

# %%
s5.duplicated()                                   # Check for duplicate values
# Out:
# 101    False
# 102    False
# 103    False
# 104    False
# 105     True
# 106    False
# 107     True
# 108     True
# 109     True
# Name: States and Capitals, dtype: bool

# %%
s5.duplicated().sum()
# Out:
# 4

# %% [markdown]
# # ==============================================
# # DataFrames

# %%
employee1 = pd.Series({'Name' : 'Utkarsh', 'ID' : 1, 'Gender' : 'Male', 'Salary':95000})
employee2 = pd.Series({'Name' : 'Kartik', 'ID' : 2, 'Gender' : 'Male','Salary':85000})
employee3 = pd.Series({'Name' : 'Aishwarya', 'ID' : 3, 'Gender' : 'Female','Salary':75000})
employee4 = pd.Series({'Name' : 'Anand', 'ID' : 4, 'Gender' : 'Male','Salary':65000})
employee5 = pd.Series({'Name' : 'Shalini', 'ID' : 5, 'Gender' : 'Female','Salary':90000})
employee6 = pd.Series({'Name' : 'Pratik', 'ID' : 6, 'Gender' : 'Male','Salary':80000})
employee7 = pd.Series({'Name' : 'Monalika', 'ID' : 7, 'Gender' : 'Female','Salary':70000})
employee8 = pd.Series({'Name' : 'Ayesha', 'ID' : 8, 'Gender' : 'Female','Salary':60000})
employee9 = pd.Series({'Name' : 'Anant', 'ID' : 9, 'Gender' : 'Male','Salary':100000})
employee10 = pd.Series({'Name' : 'Shamiksha', 'ID' : 10, 'Gender' : 'Female','Salary':45000})
employee11 = pd.Series({'Name' : 'Prashant', 'ID' : 11, 'Gender' : 'Male','Salary':55000})
employee12 = pd.Series({'Name' : 'Mohini', 'ID' : 12, 'Gender' : 'Female','Salary':65000})

# %%
employee1
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# dtype: object

# %%
employees = [employee1,employee2,employee3,employee4,employee5,employee6,employee7,employee8,employee9,employee10,employee11,employee12]
df1 = pd.DataFrame(data = employees, index = range(101,113))
df1
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000
# 104      Anand   4    Male   65000
# 105    Shalini   5  Female   90000
# 106     Pratik   6    Male   80000
# 107   Monalika   7  Female   70000
# 108     Ayesha   8  Female   60000
# 109      Anant   9    Male  100000
# 110  Shamiksha  10  Female   45000
# 111   Prashant  11    Male   55000
# 112     Mohini  12  Female   65000

# %% [markdown]
#  - Single and two dimensional data
#  - Rows and columns format
#  - Tabular data
#  - Data Frame
#  - Structured data
#  - Unstructured data

# %%
df1.head()
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000
# 104      Anand   4    Male   65000
# 105    Shalini   5  Female   90000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 101 to 112
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   ID      12 non-null     int64
#  2   Gender  12 non-null     object
#  3   Salary  12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 516.0+ bytes

# %%
df1.index
# Out:
# RangeIndex(start=101, stop=113, step=1)

# %%
df1.values
# Out:
# array([['Utkarsh', 1, 'Male', 95000],
#        ['Kartik', 2, 'Male', 85000],
#        ['Aishwarya', 3, 'Female', 75000],
#        ['Anand', 4, 'Male', 65000],
#        ['Shalini', 5, 'Female', 90000],
#        ['Pratik', 6, 'Male', 80000],
#        ['Monalika', 7, 'Female', 70000],
#        ['Ayesha', 8, 'Female', 60000],
#        ['Anant', 9, 'Male', 100000],
#        ['Shamiksha', 10, 'Female', 45000],
#        ['Prashant', 11, 'Male', 55000],
#        ['Mohini', 12, 'Female', 65000]], dtype=object)

# %%
df1.columns
# Out:
# Index(['Name', 'ID', 'Gender', 'Salary'], dtype='object')

# %%
df1.name = 'Employee_Details'
df1.index.name = 'Employee_ID'

# %%
df1.name
# Out:
# 'Employee_Details'

# %%
df1.index.name
# Out:
# 'Employee_ID'

# %% [markdown]
# ## Accessing data from DataFrame

# %%
df1
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000
# 106             Pratik   6    Male   80000
# 107           Monalika   7  Female   70000
# 108             Ayesha   8  Female   60000
# 109              Anant   9    Male  100000
# 110          Shamiksha  10  Female   45000
# 111           Prashant  11    Male   55000
# 112             Mohini  12  Female   65000

# %% [markdown]
# #### Accessing Columns

# %%
df1['Name']
# Out:
# Employee_ID
# 101      Utkarsh
# 102       Kartik
# 103    Aishwarya
# 104        Anand
# 105      Shalini
# 106       Pratik
# 107     Monalika
# 108       Ayesha
# 109        Anant
# 110    Shamiksha
# 111     Prashant
# 112       Mohini
# Name: Name, dtype: object

# %%
df1['Salary']
# Out:
# Employee_ID
# 101     95000
# 102     85000
# 103     75000
# 104     65000
# 105     90000
# 106     80000
# 107     70000
# 108     60000
# 109    100000
# 110     45000
# 111     55000
# 112     65000
# Name: Salary, dtype: int64

# %%
df1[['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 102             Kartik   85000
# 103          Aishwarya   75000
# 104              Anand   65000
# 105            Shalini   90000
# 106             Pratik   80000
# 107           Monalika   70000
# 108             Ayesha   60000
# 109              Anant  100000
# 110          Shamiksha   45000
# 111           Prashant   55000
# 112             Mohini   65000

# %%
df1.Name
# Out:
# Employee_ID
# 101      Utkarsh
# 102       Kartik
# 103    Aishwarya
# 104        Anand
# 105      Shalini
# 106       Pratik
# 107     Monalika
# 108       Ayesha
# 109        Anant
# 110    Shamiksha
# 111     Prashant
# 112       Mohini
# Name: Name, dtype: object

# %%
df1.Salary
# Out:
# Employee_ID
# 101     95000
# 102     85000
# 103     75000
# 104     65000
# 105     90000
# 106     80000
# 107     70000
# 108     60000
# 109    100000
# 110     45000
# 111     55000
# 112     65000
# Name: Salary, dtype: int64

# %% [markdown]
# #### Accessing Records (Rows)

# %%
df1.loc[101]
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# Name: 101, dtype: object

# %%
df1.iloc[0]
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# Name: 101, dtype: object

# %%
df1.loc[105]
# Out:
# Name      Shalini
# ID              5
# Gender     Female
# Salary      90000
# Name: 105, dtype: object

# %%
df1.loc[[101,105,109]]
# Out:
#                 Name  ID  Gender  Salary
# Employee_ID
# 101          Utkarsh   1    Male   95000
# 105          Shalini   5  Female   90000
# 109            Anant   9    Male  100000

# %%
df1.iloc[[0,4,6,9]]
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 105            Shalini   5  Female   90000
# 107           Monalika   7  Female   70000
# 110          Shamiksha  10  Female   45000

# %% [markdown]
# ### Accessing Specific Values

# %%
df1
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000
# 106             Pratik   6    Male   80000
# 107           Monalika   7  Female   70000
# 108             Ayesha   8  Female   60000
# 109              Anant   9    Male  100000
# 110          Shamiksha  10  Female   45000
# 111           Prashant  11    Male   55000
# 112             Mohini  12  Female   65000

# %%
df1.loc[105]['Salary']
# Out:
# 90000

# %%
df1.loc[103]['Name']
# Out:
# 'Aishwarya'

# %%
df1.iloc[4]['Salary']
# Out:
# 90000

# %%
df1.iloc[2]['Name']
# Out:
# 'Aishwarya'

# %%
df1['Salary'][105]
# Out:
# 90000

# %%
df1['Name'][103]
# Out:
# 'Aishwarya'

# %%
df1.Salary[105]
# Out:
# 90000

# %%
df1.Name[103]
# Out:
# 'Aishwarya'

# %%
df1.loc[[101,105,108]]['Salary']
# Out:
# Employee_ID
# 101    95000
# 105    90000
# 108    60000
# Name: Salary, dtype: int64

# %%
df1.loc[[101,105,108,110]][['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 105            Shalini   90000
# 108             Ayesha   60000
# 110          Shamiksha   45000

# %%
df1.iloc[[0,4,7,9]][['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 105            Shalini   90000
# 108             Ayesha   60000
# 110          Shamiksha   45000

# %%
df1.loc[105, 'Salary']                              # df1.loc[105]['Salary']
# Out:
# 90000

# %%
df1.loc[[105,108,110], 'Salary']
# Out:
# Employee_ID
# 105    90000
# 108    60000
# 110    45000
# Name: Salary, dtype: int64

# %%
df1.loc[[105,108,110, 101], ['Name','Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 105            Shalini   90000
# 108             Ayesha   60000
# 110          Shamiksha   45000
# 101            Utkarsh   95000

# %%
df1.loc[101:106]
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000
# 106             Pratik   6    Male   80000

# %%
df1.loc[101:106, ['Name','Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 101            Utkarsh   95000
# 102             Kartik   85000
# 103          Aishwarya   75000
# 104              Anand   65000
# 105            Shalini   90000
# 106             Pratik   80000

# %% [markdown]
# ## Adding and Deleting Rows and Columns

# %%
df1.loc[113] = ['Priti', 13, 'Female', 71000]
df1
# Out:
#                   Name  ID  Gender  Salary
# Employee_ID
# 101            Utkarsh   1    Male   95000
# 102             Kartik   2    Male   85000
# 103          Aishwarya   3  Female   75000
# 104              Anand   4    Male   65000
# 105            Shalini   5  Female   90000
# 106             Pratik   6    Male   80000
# 107           Monalika   7  Female   70000
# 108             Ayesha   8  Female   60000
# 109              Anant   9    Male  100000
# 110          Shamiksha  10  Female   45000
# 111           Prashant  11    Male   55000
# 112             Mohini  12  Female   65000
# 113              Priti  13  Female   71000

# %%
df1['Age'] = np.random.randint(25,50,13)
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   39
# 102             Kartik   2    Male   85000   28
# 103          Aishwarya   3  Female   75000   30
# 104              Anand   4    Male   65000   31
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 109              Anant   9    Male  100000   46
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31
# 113              Priti  13  Female   71000   35

# %%
df1.drop(113, inplace = True, axis = 0)
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   39
# 102             Kartik   2    Male   85000   28
# 103          Aishwarya   3  Female   75000   30
# 104              Anand   4    Male   65000   31
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 109              Anant   9    Male  100000   46
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31

# %%
df1['City'] = 'Jaipur'
df1
# Out:
#                   Name  ID  Gender  Salary  Age    City
# Employee_ID
# 101            Utkarsh   1    Male   95000   39  Jaipur
# 102             Kartik   2    Male   85000   28  Jaipur
# 103          Aishwarya   3  Female   75000   30  Jaipur
# 104              Anand   4    Male   65000   31  Jaipur
# 105            Shalini   5  Female   90000   41  Jaipur
# 106             Pratik   6    Male   80000   38  Jaipur
# 107           Monalika   7  Female   70000   40  Jaipur
# 108             Ayesha   8  Female   60000   33  Jaipur
# 109              Anant   9    Male  100000   46  Jaipur
# 110          Shamiksha  10  Female   45000   26  Jaipur
# 111           Prashant  11    Male   55000   46  Jaipur
# 112             Mohini  12  Female   65000   31  Jaipur

# %%
df1.drop('City', inplace = True, axis = 1)
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male   95000   39
# 102             Kartik   2    Male   85000   28
# 103          Aishwarya   3  Female   75000   30
# 104              Anand   4    Male   65000   31
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 109              Anant   9    Male  100000   46
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31

# %%
df1.loc[101, 'Salary'] = 200000
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000   39
# 102             Kartik   2    Male   85000   28
# 103          Aishwarya   3  Female   75000   30
# 104              Anand   4    Male   65000   31
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 109              Anant   9    Male  100000   46
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31

# %%
df1.loc[[102,103], 'Salary'] = [90000, 80000]
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000   39
# 102             Kartik   2    Male   90000   28
# 103          Aishwarya   3  Female   80000   30
# 104              Anand   4    Male   65000   31
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 109              Anant   9    Male  100000   46
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31

# %% [markdown]
# ## Querying Based on Condition

# %%
df1[df1.Age > 40]
# Out:
#                  Name  ID  Gender  Salary  Age
# Employee_ID
# 105           Shalini   5  Female   90000   41
# 109             Anant   9    Male  100000   46
# 111          Prashant  11    Male   55000   46

# %%
df1[df1['Salary'] < 70000]
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 104              Anand   4    Male   65000   31
# 108             Ayesha   8  Female   60000   33
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31

# %%
df1[df1.Salary < 70000][['Name', 'Salary']]
# Out:
#                   Name  Salary
# Employee_ID
# 104              Anand   65000
# 108             Ayesha   60000
# 110          Shamiksha   45000
# 111           Prashant   55000
# 112             Mohini   65000

# %%
df1[df1.Gender == 'Male']
# Out:
#                  Name  ID Gender  Salary  Age
# Employee_ID
# 101           Utkarsh   1   Male  200000   39
# 102            Kartik   2   Male   90000   28
# 104             Anand   4   Male   65000   31
# 106            Pratik   6   Male   80000   38
# 109             Anant   9   Male  100000   46
# 111          Prashant  11   Male   55000   46

# %%
df1[df1.Gender == 'Male'][df1.Salary > 80000]
# Out:
#                 Name  ID Gender  Salary  Age
# Employee_ID
# 101          Utkarsh   1   Male  200000   39
# 102           Kartik   2   Male   90000   28
# 109            Anant   9   Male  100000   46

# %%
df1[df1.Gender == 'Female'][df1.Salary < 100000]
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 103          Aishwarya   3  Female   80000   30
# 105            Shalini   5  Female   90000   41
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 110          Shamiksha  10  Female   45000   26
# 112             Mohini  12  Female   65000   31

# %%
df1[df1.Gender == 'Male'][df1.Salary > 60000][df1.Salary < 120000]
# Out:
#                Name  ID Gender  Salary  Age
# Employee_ID
# 102          Kartik   2   Male   90000   28
# 104           Anand   4   Male   65000   31
# 106          Pratik   6   Male   80000   38
# 109           Anant   9   Male  100000   46

# %%
df1[df1.Gender == 'Female'][df1.Age > 45]
# Out:
# Empty DataFrame
# Columns: [Name, ID, Gender, Salary, Age]
# Index: []

# %%
# Extract name, gender and salary or all male employees having salary between 80000 to 120000
df1[df1.Gender == 'Male'][df1.Salary >= 80000][df1.Salary <= 120000][['Name', 'Gender', 'Salary']]
# Out:
#                Name Gender  Salary
# Employee_ID
# 102          Kartik   Male   90000
# 106          Pratik   Male   80000
# 109           Anant   Male  100000

# %%
df1.query('Salary > 70000')
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000   39
# 102             Kartik   2    Male   90000   28
# 103          Aishwarya   3  Female   80000   30
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 109              Anant   9    Male  100000   46

# %%
df1.query('Gender == "Male"')
# Out:
#                  Name  ID Gender  Salary  Age
# Employee_ID
# 101           Utkarsh   1   Male  200000   39
# 102            Kartik   2   Male   90000   28
# 104             Anand   4   Male   65000   31
# 106            Pratik   6   Male   80000   38
# 109             Anant   9   Male  100000   46
# 111          Prashant  11   Male   55000   46

# %%
df1.query('Salary > 70000 and Age > 40')
# Out:
#                 Name  ID  Gender  Salary  Age
# Employee_ID
# 105          Shalini   5  Female   90000   41
# 109            Anant   9    Male  100000   46

# %%
df1.query('Salary >= 70000 and Salary <= 90000')
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 102             Kartik   2    Male   90000   28
# 103          Aishwarya   3  Female   80000   30
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40

# %%
df1.query("Gender == 'Male' and Salary >= 80000 and Salary <= 120000")[['Name', 'Gender', 'Salary']]
# Out:
#                Name Gender  Salary
# Employee_ID
# 102          Kartik   Male   90000
# 106          Pratik   Male   80000
# 109           Anant   Male  100000

# %% [markdown]
# # Important Functions

# %%
df1
# Out:
#                   Name  ID  Gender  Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000   39
# 102             Kartik   2    Male   90000   28
# 103          Aishwarya   3  Female   80000   30
# 104              Anand   4    Male   65000   31
# 105            Shalini   5  Female   90000   41
# 106             Pratik   6    Male   80000   38
# 107           Monalika   7  Female   70000   40
# 108             Ayesha   8  Female   60000   33
# 109              Anant   9    Male  100000   46
# 110          Shamiksha  10  Female   45000   26
# 111           Prashant  11    Male   55000   46
# 112             Mohini  12  Female   65000   31

# %%
df1.loc[113] = df1.loc[109]
df1.loc[114] = df1.loc[110]
df1.loc[115] = ['Kavita', 15, np.nan, 85000, 30]
df1.loc[116] = ['Pratik', 16, np.nan, np.nan, 32]
df1
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 108             Ayesha   8  Female   60000.0   33
# 109              Anant   9    Male  100000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 111           Prashant  11    Male   55000.0   46
# 112             Mohini  12  Female   65000.0   31
# 113              Anant   9    Male  100000.0   46
# 114          Shamiksha  10  Female   45000.0   26
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32

# %%
df1.head()
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41

# %%
df1.head(10)
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 108             Ayesha   8  Female   60000.0   33
# 109              Anant   9    Male  100000.0   46
# 110          Shamiksha  10  Female   45000.0   26

# %%
df1.tail()
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 112             Mohini  12  Female   65000.0   31
# 113              Anant   9    Male  100000.0   46
# 114          Shamiksha  10  Female   45000.0   26
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32

# %%
df1.tail(6)
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 111           Prashant  11    Male   55000.0   46
# 112             Mohini  12  Female   65000.0   31
# 113              Anant   9    Male  100000.0   46
# 114          Shamiksha  10  Female   45000.0   26
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32

# %%
# Check for null values
df1.isnull().sum()
# Out:
# Name      0
# ID        0
# Gender    2
# Salary    1
# Age       0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Name      0
# ID        0
# Gender    2
# Salary    1
# Age       0
# dtype: int64

# %%
# Check for duplicates
df1.duplicated().sum()
# Out:
# 2

# %%
# To drop duplicate records
df1.drop_duplicates(inplace = True)
df1
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 108             Ayesha   8  Female   60000.0   33
# 109              Anant   9    Male  100000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 111           Prashant  11    Male   55000.0   46
# 112             Mohini  12  Female   65000.0   31
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32

# %%
df1.nunique()
# Out:
# Name      13
# ID        14
# Gender     2
# Salary    10
# Age       11
# dtype: int64

# %%
df1['Salary'].nunique()
# Out:
# 10

# %%
df1['Name'].nunique()
# Out:
# 13

# %%
df1['Name'].unique()
# Out:
# array(['Utkarsh', 'Kartik', 'Aishwarya', 'Anand', 'Shalini', 'Pratik',
#        'Monalika', 'Ayesha', 'Anant', 'Shamiksha', 'Prashant', 'Mohini',
#        'Kavita'], dtype=object)

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df1['Gender'].dropna().unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1.sort_index()
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 108             Ayesha   8  Female   60000.0   33
# 109              Anant   9    Male  100000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 111           Prashant  11    Male   55000.0   46
# 112             Mohini  12  Female   65000.0   31
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32

# %%
df1.sort_index(ascending = False)
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 116             Pratik  16     NaN       NaN   32
# 115             Kavita  15     NaN   85000.0   30
# 112             Mohini  12  Female   65000.0   31
# 111           Prashant  11    Male   55000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 109              Anant   9    Male  100000.0   46
# 108             Ayesha   8  Female   60000.0   33
# 107           Monalika   7  Female   70000.0   40
# 106             Pratik   6    Male   80000.0   38
# 105            Shalini   5  Female   90000.0   41
# 104              Anand   4    Male   65000.0   31
# 103          Aishwarya   3  Female   80000.0   30
# 102             Kartik   2    Male   90000.0   28
# 101            Utkarsh   1    Male  200000.0   39

# %%
df1.sort_values(by = 'Salary')
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 110          Shamiksha  10  Female   45000.0   26
# 111           Prashant  11    Male   55000.0   46
# 108             Ayesha   8  Female   60000.0   33
# 104              Anand   4    Male   65000.0   31
# 112             Mohini  12  Female   65000.0   31
# 107           Monalika   7  Female   70000.0   40
# 103          Aishwarya   3  Female   80000.0   30
# 106             Pratik   6    Male   80000.0   38
# 115             Kavita  15     NaN   85000.0   30
# 102             Kartik   2    Male   90000.0   28
# 105            Shalini   5  Female   90000.0   41
# 109              Anant   9    Male  100000.0   46
# 101            Utkarsh   1    Male  200000.0   39
# 116             Pratik  16     NaN       NaN   32

# %%
df1.sort_values(by = 'Salary', ascending = False)
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 109              Anant   9    Male  100000.0   46
# 102             Kartik   2    Male   90000.0   28
# 105            Shalini   5  Female   90000.0   41
# 115             Kavita  15     NaN   85000.0   30
# 103          Aishwarya   3  Female   80000.0   30
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 104              Anand   4    Male   65000.0   31
# 112             Mohini  12  Female   65000.0   31
# 108             Ayesha   8  Female   60000.0   33
# 111           Prashant  11    Male   55000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 116             Pratik  16     NaN       NaN   32

# %%
df1.sort_values(by = 'Name')
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 109              Anant   9    Male  100000.0   46
# 108             Ayesha   8  Female   60000.0   33
# 102             Kartik   2    Male   90000.0   28
# 115             Kavita  15     NaN   85000.0   30
# 112             Mohini  12  Female   65000.0   31
# 107           Monalika   7  Female   70000.0   40
# 111           Prashant  11    Male   55000.0   46
# 106             Pratik   6    Male   80000.0   38
# 116             Pratik  16     NaN       NaN   32
# 105            Shalini   5  Female   90000.0   41
# 110          Shamiksha  10  Female   45000.0   26
# 101            Utkarsh   1    Male  200000.0   39

# %%
df1.sort_values(by = ['Age', 'Salary'])
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 110          Shamiksha  10  Female   45000.0   26
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 115             Kavita  15     NaN   85000.0   30
# 104              Anand   4    Male   65000.0   31
# 112             Mohini  12  Female   65000.0   31
# 116             Pratik  16     NaN       NaN   32
# 108             Ayesha   8  Female   60000.0   33
# 106             Pratik   6    Male   80000.0   38
# 101            Utkarsh   1    Male  200000.0   39
# 107           Monalika   7  Female   70000.0   40
# 105            Shalini   5  Female   90000.0   41
# 111           Prashant  11    Male   55000.0   46
# 109              Anant   9    Male  100000.0   46

# %%
pd.concat([df1,df1],axis = 0)
# Out:
#                   Name  ID  Gender    Salary  Age
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 108             Ayesha   8  Female   60000.0   33
# 109              Anant   9    Male  100000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 111           Prashant  11    Male   55000.0   46
# 112             Mohini  12  Female   65000.0   31
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32
# 101            Utkarsh   1    Male  200000.0   39
# 102             Kartik   2    Male   90000.0   28
# 103          Aishwarya   3  Female   80000.0   30
# 104              Anand   4    Male   65000.0   31
# 105            Shalini   5  Female   90000.0   41
# 106             Pratik   6    Male   80000.0   38
# 107           Monalika   7  Female   70000.0   40
# 108             Ayesha   8  Female   60000.0   33
# 109              Anant   9    Male  100000.0   46
# 110          Shamiksha  10  Female   45000.0   26
# 111           Prashant  11    Male   55000.0   46
# 112             Mohini  12  Female   65000.0   31
# 115             Kavita  15     NaN   85000.0   30
# 116             Pratik  16     NaN       NaN   32

# %%
pd.concat([df1,df1], axis = 1)
# Out:
#                   Name  ID  Gender    Salary  Age       Name  ID  Gender  \
# Employee_ID
# 101            Utkarsh   1    Male  200000.0   28    Utkarsh   1    Male
# 102             Kartik   2    Male   90000.0   31     Kartik   2    Male
# 103          Aishwarya   3  Female   80000.0   33  Aishwarya   3  Female
# 104              Anand   4    Male   65000.0   48      Anand   4    Male
# 105            Shalini   5  Female   90000.0   35    Shalini   5  Female
# 106             Pratik   6    Male   80000.0   43     Pratik   6    Male
# 107           Monalika   7  Female   70000.0   33   Monalika   7  Female
# 108             Ayesha   8  Female   60000.0   37     Ayesha   8  Female
# 109              Anant   9    Male  100000.0   41      Anant   9    Male
# 110          Shamiksha  10  Female   45000.0   34  Shamiksha  10  Female
# 111           Prashant  11    Male   55000.0   28   Prashant  11    Male
# 112             Mohini  12  Female   65000.0   47     Mohini  12  Female
# 115             Kavita  15     NaN       NaN   30     Kavita  15     NaN
# 116             Pratik  16     NaN       NaN   32     Pratik  16     NaN
#
#                Salary  Age
# Employee_ID
# 101          200000.0   28
# 102           90000.0   31
# 103           80000.0   33
# 104           65000.0   48
# 105           90000.0   35
# 106           80000.0   43
# 107           70000.0   33
# 108           60000.0   37
# 109          100000.0   41
# 110           45000.0   34
# 111           55000.0   28
# 112           65000.0   47
# 115               NaN   30
# 116               NaN   32

# %%
df1.Salary.value_counts()
# Out:
# 65000.0     2
# 80000.0     2
# 90000.0     2
# 55000.0     1
# 200000.0    1
# 85000.0     1
# 60000.0     1
# 45000.0     1
# 70000.0     1
# 100000.0    1
# Name: Salary, dtype: int64

# %%
df1.Gender.value_counts()
# Out:
# Female    6
# Male      6
# Name: Gender, dtype: int64

# %%
df1.Gender.value_counts(normalize = True)
# Out:
# Female    0.5
# Male      0.5
# Name: Gender, dtype: float64

# %%
df1.describe()
# Out:
#               ID         Salary        Age
# count  14.000000      13.000000  14.000000
# mean    7.785714   83461.538462  35.071429
# std     4.660448   38372.332447   6.521730
# min     1.000000   45000.000000  26.000000
# 25%     4.250000   65000.000000  30.250000
# 50%     7.500000   80000.000000  32.500000
# 75%    10.750000   90000.000000  39.750000
# max    16.000000  200000.000000  46.000000

# %%
df1[['Age','Salary']].describe()
# Out:
#              Age         Salary
# count  14.000000      13.000000
# mean   35.071429   83461.538462
# std     6.521730   38372.332447
# min    26.000000   45000.000000
# 25%    30.250000   65000.000000
# 50%    32.500000   80000.000000
# 75%    39.750000   90000.000000
# max    46.000000  200000.000000

# %%
df1.count()
# Out:
# Name      14
# ID        14
# Gender    12
# Salary    13
# Age       14
# dtype: int64

# %%
df1.mean()
# Out:
# ID            7.785714
# Salary    83461.538462
# Age          35.071429
# dtype: float64

# %%
df1['Salary'].mean()        # df1.Salary.mean()
# Out:
# 83461.53846153847

# %%
df1.var()
# Out:
# ID        2.171978e+01
# Salary    1.472436e+09
# Age       4.253297e+01
# dtype: float64

# %%
df1.std()
# Out:
# ID            4.660448
# Salary    38372.332447
# Age           6.521730
# dtype: float64

# %%
df1.median()
# Out:
# ID            7.5
# Salary    80000.0
# Age          32.5
# dtype: float64

# %%
df1['Age'].mode()
# Out:
# 0    30
# 1    31
# 2    46
# dtype: int64

# %%
df1.Age.value_counts()
# Out:
# 46    2
# 30    2
# 31    2
# 32    1
# 33    1
# 38    1
# 39    1
# 40    1
# 41    1
# 26    1
# 28    1
# Name: Age, dtype: int64

# %%
df1.Age.quantile(0.25)
# Out:
# 30.25

# %%
df1.Age.quantile(0.5)
# Out:
# 32.5

# %%
df1.Age.quantile(0.75)
# Out:
# 39.75

# %%
df1['Salary'].apply(np.sqrt)
# Out:
# Employee_ID
# 101    447.213595
# 102    300.000000
# 103    282.842712
# 104    254.950976
# 105    300.000000
# 106    282.842712
# 107    264.575131
# 108    244.948974
# 109    316.227766
# 110    212.132034
# 111    234.520788
# 112    254.950976
# 115    291.547595
# 116           NaN
# Name: Salary, dtype: float64

# %%
df1['Salary'].apply(lambda num : 1.1 * num)
# Out:
# Employee_ID
# 101    220000.0
# 102     99000.0
# 103     88000.0
# 104     71500.0
# 105     99000.0
# 106     88000.0
# 107     77000.0
# 108     66000.0
# 109    110000.0
# 110     49500.0
# 111     60500.0
# 112     71500.0
# 115     93500.0
# 116         NaN
# Name: Salary, dtype: float64

# %%
df1.groupby(by = 'Gender')['Age'].mean()
# Out:
# Gender
# Female    33.5
# Male      38.0
# Name: Age, dtype: float64

# %%
df1.groupby(by = 'Gender')['Salary'].mean()
# Out:
# Gender
# Female    68333.333333
# Male      98333.333333
# Name: Salary, dtype: float64

# %%
df1.corr()
# Out:
#               ID    Salary       Age
# ID      1.000000 -0.504931 -0.057667
# Salary -0.504931  1.000000  0.258702
# Age    -0.057667  0.258702  1.000000

# %% [markdown]
# # -------------------------------------------------------------------------------------
# ## Dealing With CSV Files

# %%
data = pd.read_csv('Automobile_Data.csv')
data.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 5        sedan          fwd           front        99.8  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 7        wagon          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 9    hatchback          4wd           front        99.5  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
# 5         mpfi  3.19     3.4               8.5        110      5500       19
# 6         mpfi  3.19     3.4               8.5        110      5500       19
# 7         mpfi  3.19     3.4               8.5        110      5500       19
# 8         mpfi  3.13     3.4               8.3        140      5500       17
# 9         mpfi  3.13     3.4               7.0        160      5500       16
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22      ?
#
# [10 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.replace('?', np.nan, inplace =True)

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data.nunique()
# Out:
# symboling              6
# normalized-losses     51
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  38
# stroke                36
# compression-ratio     32
# horsepower            59
# peak-rpm              23
# city-mpg              29
# highway-mpg           30
# price                186
# dtype: int64

# %%
print('Fuel Types   : ',data['fuel-type'].unique())
print('Body Styles  : ',data['body-style'].unique())
print('Drive Wheels : ',data['drive-wheels'].unique())
print('Fuel System  : ',data['fuel-system'].unique())
print('Engine Type  : ',data['engine-type'].unique())
# Out:
# Fuel Types   :  ['gas' 'diesel']
# Body Styles  :  ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# Drive Wheels :  ['rwd' 'fwd' '4wd']
# Fuel System  :  ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# Engine Type  :  ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']

# %%
data['city-mpg'].mean()
# Out:
# 25.21951219512195

# %%
data.groupby(by = 'fuel-type')['city-mpg'].mean()
# Out:
# fuel-type
# diesel    30.30000
# gas       24.67027
# Name: city-mpg, dtype: float64

# %%
data['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
data.groupby(by = 'body-style')['highway-mpg'].mean()
# Out:
# body-style
# convertible    26.000000
# hardtop        27.250000
# hatchback      32.171429
# sedan          30.833333
# wagon          28.720000
# Name: highway-mpg, dtype: float64

# %%
data.groupby(by = 'aspiration')['highway-mpg'].mean().sort_values(ascending = False)
# Out:
# aspiration
# std      31.571429
# turbo    27.027027
# Name: highway-mpg, dtype: float64

# %%
data.groupby(by = 'aspiration')['city-mpg'].mean().sort_values(ascending = False)
# Out:
# aspiration
# std      25.839286
# turbo    22.405405
# Name: city-mpg, dtype: float64

# %%
data.groupby(by = ['body-style','fuel-type'])['city-mpg'].mean()
# Out:
# body-style   fuel-type
# convertible  gas          20.500000
# hardtop      diesel       22.000000
#              gas          21.571429
# hatchback    diesel       38.000000
#              gas          26.144928
# sedan        diesel       31.600000
#              gas          24.160494
# wagon        diesel       24.000000
#              gas          24.045455
# Name: city-mpg, dtype: float64

# %%
data.groupby(by = ['aspiration','fuel-type'])['city-mpg'].mean()
# Out:
# aspiration  fuel-type
# std         diesel       36.857143
#             gas          25.360248
# turbo       diesel       26.769231
#             gas          20.041667
# Name: city-mpg, dtype: float64

# %%
data.groupby(by = ['fuel-type','aspiration'])['city-mpg'].mean()
# Out:
# fuel-type  aspiration
# diesel     std           36.857143
#            turbo         26.769231
# gas        std           25.360248
#            turbo         20.041667
# Name: city-mpg, dtype: float64
