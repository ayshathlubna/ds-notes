# %%
import numpy

# %%
nums = [10,50,40,30,70,80,20]
numpy.mean(nums)
# Out:
# 42.857142857142854

# %%
numpy.var(nums)
# Out:
# 563.2653061224489

# %%
numpy.std(nums)
# Out:
# 23.733211036908784

# %%
round(numpy.mean(nums),2)
# Out:
# 42.86

# %%
! conda list
# Out:
# # packages in environment at C:\Users\Utkarsh\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# absl-py                   0.12.0                   pypi_0    pypi
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        2.0.1                    py38_0
# anyio                     2.2.0            py38haa95532_2
# argon2-cffi               20.1.0           py38h2bbff1b_1
# astunparse                1.6.3                    pypi_0    pypi
# async_generator           1.10               pyhd3eb1b0_0
# attrs                     20.3.0             pyhd3eb1b0_0
# babel                     2.9.0              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports                 1.0                pyhd3eb1b0_2
# backports.functools_lru_cache 1.6.4              pyhd3eb1b0_0
# backports.tempfile        1.0                pyhd3eb1b0_1
# ...

# %%
import numpy as np

# %%
np.mean([0,20,30,40,50])
# Out:
# 28.0

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.plot([1,2,3,4,5], [2,4,6,8,10])

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5], [2,4,6,8,10])

# %%
nums = [10,20,30,40,50,60,70,80,90]

# %%
from numpy import mean

# %%
mean(nums)
# Out:
# 48.888888888888886

# %% [markdown]
# # Numpy
# # Pandas
# # Matplotlib
# # Seaborn

# %%
import numpy                                           # importing the library
import numpy as np                                     # importing library with a different name
from numpy import mean                                 # importing a specific class or function

# %%
import numpy as np                                      # numerical computation
import pandas as pd                                     # data manipulation
import matplotlib.pyplot as plt                         # data visualisation
import seaborn as sns                                   # data visualization

# %%
for i in range(10):
    for j in range(i,i+1,2):
        print('haha')
# Out:
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
