# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %matplotlib inline

# %%
weights = [65,66,65,67,68,70,71,73,74,76,75,78,79,81,83,85,86,87,88,90]

plt.figure(figsize = (12,5), dpi = 200)
sns.boxplot(y = weights)
# Out:
# <AxesSubplot:>

# %%
weights = [40,65,66,65,67,68,70,71,73,74,76,75,78,79,81,83,85,86,87,88,90,110]

plt.figure(figsize = (12,5), dpi = 200)
sns.boxplot(y = weights)
# Out:
# <AxesSubplot:>

# %%
weights = np.array([65,66,65,67,68,70,71,73,74,76,75,78,79,81,83,85,86,87,88,90])
avg_weight = weights.mean()
avg_weight
# Out:
# 76.35

# %%
std_weight = weights.std()
std_weight
# Out:
# 8.026674280173577

# %%
(65 - avg_weight)/ std_weight
# Out:
# -1.4140352036004817

# %%
weights = np.array([65,66,65,67,68,70,71,73,74,76,75,78,79,81,83,85,86,87,88,90,120])

avg_weight = weights.mean()
avg_weight
# Out:
# 78.42857142857143

# %%
std_weight = weights.std()
std_weight
# Out:
# 12.15601527981078

# %%
(65 - avg_weight) / std_weight
# Out:
# -1.1046853034870863

# %%
(120 - avg_weight) / std_weight
# Out:
# 3.41982365228449

# %%
z_scores = (weights - avg_weight) / std_weight
z_scores
# Out:
# array([-1.1046853 , -1.0224215 , -1.1046853 , -0.94015771, -0.85789391,
#        -0.69336631, -0.61110251, -0.44657491, -0.36431111, -0.19978351,
#        -0.28204731, -0.03525591,  0.04700789,  0.21153548,  0.37606308,
#         0.54059068,  0.62285448,  0.70511828,  0.78738208,  0.95190968,
#         3.41982365])
