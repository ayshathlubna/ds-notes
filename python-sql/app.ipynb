# %%
import sys
from dbhelper import DBhelper
class Flipkart:
    def __init__(self):
        self.db =DBhelper()
        self.menu()

    def menu(self):
        user_input = input('''
        1.Enter 1 to register
        2.Enter 2 to login
        3.Anything else to leave
        ''')
        if user_input == "1":
            self.register()
        elif user_input =="2":
            self.login()
        else:
            sys.exit(1000)

    def register(self):
        pass

obj = Flipkart()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1148\1865427255.py in <module>
#       1 import sys
# ----> 2 from dbhelper import DBhelper
#       3 class Flipkart:
#       4     def __init__(self):
#       5         self.db =DBhelper()
#
# ModuleNotFoundError: No module named 'dbhelper'
